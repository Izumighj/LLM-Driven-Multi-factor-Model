# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1= pd.read_csv('data/Barra_data1.csv',index_col=0)

# %%
df1
# Out:
#            date   stocknames   capital       ret industry      size      beta  \
# 0    2005-04-08  000001.XSHE   95.6957  0.025478    HY007  0.406866       NaN
# 1    2005-04-08  000002.XSHE   91.9302 -0.017094    HY011  0.408722       NaN
# 2    2005-04-08  000009.XSHE   17.9650 -0.025000    HY003 -0.442991       NaN
# 3    2005-04-08  000012.XSHE    9.4199 -0.013986    HY002 -0.047540       NaN
# 4    2005-04-08  000016.XSHE   10.4245  0.000000    HY004 -0.477167       NaN
# ..          ...          ...       ...       ...      ...       ...       ...
# 295  2008-07-22  601919.XSHG  381.5692 -0.009174    HY003  0.316908  0.548508
# 296  2008-07-22  601939.XSHG  535.5000  0.011364    HY007  0.428130 -0.576318
# 297  2008-07-22  601988.XSHG  265.5844 -0.008230    HY007  0.428130 -0.827416
# 298  2008-07-22  601991.XSHG  421.4186 -0.024390    HY010  0.115472  0.638875
# 299  2008-07-22  601998.XSHG  128.9082  0.012531    HY007  0.316992  0.110834
#
# ...
